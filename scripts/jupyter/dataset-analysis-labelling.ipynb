# %% [markdown]
# ## Annotation analisys (labelling)
#
# This notebook is an attempt to compute dynamic statistics of the Superconductor dataset tags and labels.

# %%
import os
from difflib import SequenceMatcher
from pathlib import Path

from bs4 import BeautifulSoup, NavigableString, Tag
from supermat.grobid_tokenizer import tokenizeSimple

# %%
from supermat.supermat_tei_parser import get_sentences_nodes

def process_dir(input):
    # xdir = Path('/data/workspace/Suzuki/supercon_files_20190808/iop/data/')
    # xmlfiles = [x for x in xdir.glob('**/*.xml')]
    # pdffiles = [x for x in xdir.glob('**/*.pdf')]
    accumulated_statistics = []
    for root, dirs, files in os.walk(input):
        for file_ in files:
            if not file_.lower().endswith(".xml"):
                continue
            abs_path = os.path.join(root, file_)
            print("Processing: " + str(abs_path))
            output_data = process_file(abs_path)
            accumulated_statistics.append(output_data)

    return accumulated_statistics


def process_file(input):
    with open(input, encoding='utf-8') as fp:
        doc = fp.read()

    soup = BeautifulSoup(doc, 'xml')

    entities_statistics = {}
    document_statistics = {
        'name': Path(input).name,
        'path': str(Path(input).absolute()),
        'paragraphs': 0,
        'sentences': 0,
        'tokens': 0,
        'entities': 0,
        'uniq_entities': 0,
        'classes': 0,
        'entities_statistics': entities_statistics
    }
    
    sentences_by_paragraph = get_sentences_nodes(soup, grouped=True)
    
    for paragraph in sentences_by_paragraph:
        document_statistics['paragraphs'] += 1
        for sentence in paragraph:
            document_statistics['sentences'] += 1
            j = 0
            paragraphText = ''
            for item in sentence.contents:
                if type(item) == NavigableString:
                    paragraphText += str(item)

                elif type(item) is Tag and item.name == 'rs':
                    paragraphText += item.text
                    document_statistics['entities'] += 1
                    tag_content = item.text
                    paragraphText += str(item.text)
                    if 'type' not in item.attrs:
                        raise Exception("RS without type is invalid. Stopping")

                    tag_name = item.attrs['type']

                    if tag_name not in entities_statistics:
                        entities_statistics[tag_name] = {
                            'count': 1,
                            'content_distribution': {
                                tag_content: 1
                            }
                        }
                    else:
                        content_ = entities_statistics[tag_name]
                        content_['count'] += 1
                        if tag_content not in content_['content_distribution']:
                            content_['content_distribution'][tag_content] = 1
                        else:
                            content_['content_distribution'][tag_content] += 1

            document_statistics['tokens'] += len(tokenizeSimple(paragraphText))
            document_statistics['classes'] = len(set(entities_statistics.keys()))

    uniq_entities = 0
    for key in entities_statistics:
        uniq_entities += len(entities_statistics[key]['content_distribution'])

    document_statistics['uniq_entities'] = uniq_entities

    ## Cross checks

    # Verify that the sum of the content distribution corresponds to the tag distribution
    total_entities = 0
    for tag in entities_statistics:
        count = entities_statistics[tag]['count']
        sum_content_distributions = 0
        content_distribution_dict = entities_statistics[tag]['content_distribution']
        for content in content_distribution_dict:
            sum_content_distributions += content_distribution_dict[content]

        assert "Number of total entities per tag does not correspond to the sum.", count == sum_content_distributions
        total_entities += count

    assert "Number of total entities per documnent does not correspond to the sum.", total_entities == \
                                                                                     document_statistics['entities']

    return document_statistics


def group_by_with_soft_matching(input_list, threshold):
    matching = {}
    last_matching = -1

    for index_x, x in enumerate(input_list):
        unpacked = [y for x in matching for y in matching[x]]
        if x not in matching and x not in unpacked:
            matching[x] = []

            for index_y, y in enumerate(input_list[index_x + 1:]):
                if x == y:
                    continue

                if SequenceMatcher(None, x.lower(), y.lower()).ratio() > threshold:
                    matching[x].append(y)

        else:
            continue

    return matching


def aggregate(entities_statistics, threshold):
    """
    Aggregate the statistics by merging content belonging to the same entity:
     - variation of expressions (e.g. cuprates, cuprate, Cuprates, ...)
     - synonyms (e.g. 111, cuprates, ...)

    :param document_statistics:
    :param threshold:
    :return: an aggregated statistics for documents
    """

    agg = {}

    for tag in entities_statistics:
        if tag == 'tcValue' or tag == 'pressure':
            continue

        distribution = entities_statistics[tag]["content_distribution"]

        content_list = sorted(distribution.keys())
        # hash_list = []
        # for content in content_list:
        #     hash_value = content.lower().replace(" ", "")
        #     hash_list.append((hash_value, content))

        aggregated = group_by_with_soft_matching(content_list, threshold)

        agg[tag] = aggregated

        assert "Total number of element does not corresponds with the aggregated ones", len(content_list) == (
                len(agg.keys()) + len([y for x in aggregated for y in aggregated[x]]))

    return agg


def extract_csv(output_data):
    entity_statistics = output_data['entities_statistics']
    csv_rows = []
    for tag in entity_statistics:
        for content in entity_statistics[tag]['content_distribution']:
            row = [tag, content, entity_statistics[tag]['content_distribution'][content]]
            csv_rows.append(row)

    return csv_rows


def intersection(lst1, lst2):
    # Use of hybrid method
    temp = set(lst2)
    lst3 = [value for value in lst1 if value in temp]
    return lst3


def extract_inconsistencies(output_data):
    entity_statistics = output_data['entities_statistics']
    summary_content = {}
    for tag in entity_statistics:
        for content in entity_statistics[tag]['content_distribution']:
            if tag in summary_content:
                summary_content[tag].append(content)
            else:
                summary_content[tag] = [content]

    inconsistencies = []

    tags = list(summary_content.keys())
    for id1 in range(0, len(tags)):
        for id2 in range(id1 + 1, len(tags)):
            tag1 = tags[id1]
            tag2 = tags[id2]

            tag1_content = summary_content[tag1]
            tag2_content = summary_content[tag2]

            intersected_content = intersection(tag1_content, tag2_content)

            if len(intersected_content) > 0:
                for intersected_content_ in intersected_content:
                    frequency1 = entity_statistics[tag1]['content_distribution'][intersected_content_]
                    frequency2 = entity_statistics[tag2]['content_distribution'][intersected_content_]
                    intersected_tags = [(tag1, frequency1), (tag2, frequency2)]
                    inconsistencies.append([intersected_content_, tag1, frequency1, tag2, frequency2])

    return inconsistencies

def find_longest_entities(output_data, topValues=10): 
    print(output_data)

# %% [markdown]
# Analysis

# %%
def run_analysis(input): 
    output_data = {}

    input_path = Path(input)
    documents_statistics = process_dir(input_path)

    aggregated_entities_statistics = {}
    output_data = {
        'path': str(Path(input_path).absolute()),
        'files': len(documents_statistics),
        'paragraphs': 0,
        'sentences': 0,
        'tokens': 0,
        'entities': 0,
        'uniq_entities': 0,
        'classes': 0,
        'entities_statistics': aggregated_entities_statistics
    }

    classes = []

    ## Summary of all articles

    for document_statistics in documents_statistics:
        output_data['paragraphs'] += document_statistics['paragraphs']
        output_data['sentences'] += document_statistics['sentences']
        output_data['tokens'] += document_statistics['tokens']
        output_data['entities'] += document_statistics['entities']
        output_data['uniq_entities'] += document_statistics['uniq_entities']

        for tag in document_statistics['entities_statistics']:
            classes.append(tag)
            tag_statistics = document_statistics['entities_statistics'][tag]
            if tag not in aggregated_entities_statistics:
                aggregated_entities_statistics[tag] = tag_statistics
            else:
                count = tag_statistics['count']
                aggregated_entities_statistics[tag]['count'] += count

                dist = tag_statistics['content_distribution']
                aggregated_distribution = aggregated_entities_statistics[tag]['content_distribution']

                for content in dist:
                    if content not in aggregated_distribution:
                        aggregated_distribution[content] = dist[content]
                    else:
                        aggregated_distribution[content] += dist[content]

        output_data['classes'] = len(set(classes))

    output_data['documents'] = documents_statistics
    output_data['aggregated_statistics'] = aggregate(aggregated_entities_statistics, 0.90)
    output_data["inconsistencies"] = extract_inconsistencies(output_data)
    
    #find_longest_entities(output_data)

    return output_data

# %% [markdown]
# Run Analysis

# %%
input = "../../data/dataset/annotations/xml/final"
    
result = run_analysis(input)
# Out:
# Processing: ../../data/dataset/annotations/xml/final/batch-7/PR06014617-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-7/PR06114956-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-7/PR05003221-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-7/PR05713422-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-7/PR05514152-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-7/PR05814617-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-7/PR06103808-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-7/PR06103604-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-7/PR04310568-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-7/PR06013094-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-7/PR05809504-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-7/PR06100107-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-7/PR06012475-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-7/PR05009672-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-7/PR05903948-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-7/PR0446999-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-7/PR05914099-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-7/PR05511832-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-7/PR06015055-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-7/PR05907184-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-7/PR06006991-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-7/PR04909084-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-7/PR05814581-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-7/PR06114350-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-1/SST01600L7-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-1/PhysRevX.9.021044-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-1/EPL0580589.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-1/Tanaka_etal_2017-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-1/Drozdov_etal_2015.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-1/L088227002-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-1/SSC1310125-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-1/L093156802-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-1/L095167004-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-1/L094047001-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-1/L094037007-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-1/L093157004-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-1/L090137002-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-1/Li_2018_Supercond._Sci._Technol._31_085001.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-1/SSC1280097-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-1/EPL0410207-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-1/L094047006-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-1/L091217001-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-1/L088207005-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-1/L094127001-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-1/SSC1270493-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-1/SSC1230017-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-1/PhysRevX.8.041024-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-1/EPJ0290369-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-1/APL0774202-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-1/L088207003-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-1/Liu_2018_Supercond._Sci._Technol._31_125011-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-1/L090137001-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-1/L095117006-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-1/1609.04957-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-1/1903.04321-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-1/L092157004-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-1/Carnicom_2018_Supercond._Sci._Technol._31_115005.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-1/JPS081033701-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-1/L089147002-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-1/L088167005-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-1/L091087001-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-1/JPS081113707-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-1/Suzuki_etal_2015-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-1/EPL0330153-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-1/L092227003-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-1/SST0180041-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-6/xing2014theAnomaly-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-6/kotegawa2008abrupt-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-6/yamaguchi2014ac.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-6/sun2012re-emerging-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-6/piva2015combined-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-6/wang2011effect.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-6/kotegawa2009contrasting-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-6/ivanovskii2008newHigh.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-6/ying2011pressure-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-6/okada2008supercondctivity-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-6/hott2013review-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-6/chu2009high-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-6/mydeen2010temperature-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-8/SCinTiO_1612.02502-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-8/CoA4_HTSC_theory1807.00934-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-8/Tc4k_interfaceBi_Ni-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-8/1802.03907-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-8/1802.09882-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-8/Rb2Cr3As3_quasi1D_SC1412.2596-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-8/HfV2O431805.08285-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-3/MAT0305503-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-3/MAT0106521-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-3/P066024502-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-3/P066132510-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-3/P066020501-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-3/P067172501-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-3/P066024503-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-3/NAT3500600.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-3/P066214509-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-3/P065172501-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-3/P066104528-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-3/P063224522-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-3/P065224520-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-3/P064172514-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-3/P065024523-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-3/P066020503-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-3/MPL0150497-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-3/P067104503-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-3/P064144524-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-3/P065104523-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-4/P068214517-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-4/P070020503-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-4/PHC1910237.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-4/P072220505-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-4/P072174508-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-4/PCS2739-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-4/P072180504-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-4/P068100502-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-4/P069014507-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-4/PHB1480442.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-4/P071184510-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-4/P072094504-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-4/P072104504-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-4/P071104513-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-4/P068132504-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-4/P069184513-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-4/P070052502-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-4/P071100502-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-4/P071104516-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-4/P072064520-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-4/P070054519-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-4/P071134526-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-4/P068064507-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-4/P072064527-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-4/PHC1580178.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-4/P072214523-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-4/P068132507-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-4/P072224509-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-4/P069174506-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-4/P072014504-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-4/P070214505-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-4/P068180505-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-5/PHC4020027-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-5/PHC4030200-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-5/PHC3200009-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-5/PHC3411655-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-5/PHC3410729-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-5/PHC3830337-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-5/PHC2240263-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-5/PHC2640145-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-5/PHC4210001-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-5/PHC4200023-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-5/PHC4020152-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-5/PHC4170033-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-5/PHC1980027.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-5/PHC3660299-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-2/JPS0731297-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-2/JPS0731131-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-2/JP01103169-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-2/JPS0722453-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-2/JPS0710709-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-2/JPS0731655-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-2/JPS0730819-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-2/JPS0731123-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-2/EPL0490086-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-2/JPS0732912-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-2/JPS0723041-CC.superconductors.tei.xml
# Processing: ../../data/dataset/annotations/xml/final/batch-2/JPC0150L17-CC.superconductors.tei.xml

# %% [markdown]
# Extract summary on class repartition by frequency

# %%
columns=['files', 'paragraphs', 'sentences', 'tokens', 'entities', 'uniq_entities', 'classes']
rows = [result[c] for c in columns]

import pandas as pd
pd.DataFrame([rows], columns=columns)
# Out:
#    files  paragraphs  sentences   tokens  entities  uniq_entities  classes
# 0    164        3987      20807  1594023     18698           8875        6

# %%
aggregated_statistics = result['aggregated_statistics']
entities_statistics = result['entities_statistics']

# print(json.dumps(entities_statistics, indent=4))

labels = []
values = []

for label in entities_statistics.keys(): 
    labels.append(label)
    values.append(entities_statistics[label]['count'])

    
## PIE
import matplotlib.pyplot as plt
import numpy as np

def func(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%\n({:d})".format(pct, absolute)
    

fig, ax = plt.subplots(figsize=(4, 8), subplot_kw=dict(aspect="equal"))

wedges, texts, autotexts = ax.pie(values, autopct=lambda pct: func(pct, values),
                                  textprops=dict(color="w"))


ax.legend(wedges, labels,
          title="Labels",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=8, weight="bold")
ax.set_title("Class repartition by frequency")
plt.show()

## HISTOGRAM

plt.rcdefaults()
fig, ax = plt.subplots()

ax.barh(labels, values, align='center')
ax.set_yticklabels(labels)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Frequency')
ax.set_title('Class repartition by frequency')

plt.show()

#csv_row = extract_csv(output_data)
# Out:
# /var/folders/mk/scd8428n18jfgh3jdthbvpz00000gn/T/ipykernel_89212/436060154.py:44: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(labels)

# %% [markdown]
# # Inconsistencies
#
# In the following section we show annotations that have been annotated in different ways.
# For example if a certain name "xyz" has been annotated twice with two different annotations, it is listed under here.
#
#
# This doesn't means necessarly it's an error. We can conclude that the inconsistency tc-material can be attributed to mistakes, while material-class is due to ambiguities and overlapping in the definition of both labels where the outcome depends strongly from the context.

# %%
inconsistent_classes = result["inconsistencies"]

# print(inconsistent_classes)

rows = inconsistent_classes
columns=['name', 'class 1', 'frequency', 'class 2', 'frequency']
    
import pandas as pd
pd.DataFrame(rows, columns=columns)
# Out:
#                                    name   class 1  frequency    class 2  \
# 0                       zero-resistance        tc          7  me_method
# 1                    diamagnetic signal        tc          1  me_method
# 2                        sulfur hydride     class          6   material
# 3      sulfur hydride\n                     class          1   material
# 4                                 Na111     class          6   material
# 5                                 Ba122     class          4   material
# 6                                Sm1111     class          2   material
# 7                               LaOFeAs     class          1   material
# 8                               LnOFeAs     class          1   material
# 9                               LnFeAsO     class          1   material
# 10                                   Cu     class          1   material
# 11                          RNi 2 B 2 C     class          1   material
# 12                                  011     class          1   material
# 13  cobalt oxyhydrate\n                     class          1   material
# 14                              Ru-2122     class          2   material
# 15                               La-214     class          4   material
# 16                              Bi-2212     class          1   material
# 17                                Y-123     class          2   material
# 18                              Ru-1212     class          2   material
# 19                              Zn-free     class          1   material
# 20                              Mo-1222     class          1   material
# 21                              Hg-2212     class          6   material
# 22                              Hg-1212     class          2   material
# 23                                Y-124     class          1   material
# 24       cobalt oxide\n                     class          1   material
# 25                      bilayer-hydrate     class          1   material
# 26                              Zn-free     class          1    tcValue
# 27                              Zn-free  material          6    tcValue
# 28                                    0   tcValue          1   pressure
#
#     frequency
# 0           1
# 1           1
# 2           8
# 3           2
# 4           1
# 5           3
# 6           1
# 7          55
# 8          14
# 9           1
# 10          5
# 11          3
# 12          3
# 13          1
# 14          9
# 15          3
# 16         50
# 17         54
# 18         17
# 19          6
# 20          7
# 21         15
# 22          2
# 23         19
# 24          1
# 25          2
# 26          1
# 27          1
# 28          7

# %% [markdown]
# The following code identifies content in entities that it's length is more than 400% the average length of the content for each class.

# %%
# pprint.PrettyPrinter().pprint(result['entities_statistics'])

for label, value in result['entities_statistics'].items(): 
    print(label)
    average = 0
    total = 0
    for content, count in result['entities_statistics'][label]['content_distribution'].items(): 
        average += len(content)
        total +=1
    
    average = average / total
    for content, count in result['entities_statistics'][label]['content_distribution'].items(): 
        if((len(content) / average) * 100) > 400:
            print(content)
            
    print("")
# Out:
# tc
# Tc was defined as a temperature where the diamagnetic signal reaches 50% of perfect
#                         diamagnetism
#
#
# class
# M 5 X 3
#                     (M=alkaline earth or transition metal, and X=main group elements including Al, Si and As
#                     families)
# M m
#                     A 2k B s Cu 1+k O m+4k+2s±δ (M-m(2k)s(1+k); category-B)
#
# rare-earth (Ln) and transition (M) metals LnOMPn, where Pn is pnictogen (p is an element of the nitrogen subgroup
# pyridine
#                     intercalated transition metal dicalcogenides
#
#
# material
# orthorhombic 11 YBa 2 Cu 3 O 7−δ (which has two CuO 2 planes per unit cell as well as Cu-O chains) with δ = 0.0, 0.3 and 0.43
# (1-x/2)La 2 O 3 /xSrCO 3 /CuO in
#                     molar ratio with x = 0.063, 0.07, 0.09, 0.10, 0.111 and 0.125
# La 2-x Sr x CuO 4 thin films with Sr content x = 0.045,
#                         0.050, 0.055, 0.060, 0.100, 0.200, 0.250 and 0.270
# optimally doped Nd 1.85 Ce 0.15 CuO
#                     4−y (NCCO) and Pr 1.85 Ce 0.15 CuO 4−y (PCCO) films
#
# La 2−x Ce x CuO 4−δ (LCCO) and Pr 2−x Ce x CuO 4−δ
#                     (PCCO) films grown directly on SrTiO 3 substrates
# Pr 0.5 Ca 0.5 Ba 2 Cu 3 O 7−δ thin films grown on the substrates
#                         of SrTiO 3 and Yttrium-stabilized ZrO 2
#
# Sr x K 1Àx Fe 2 As 2 crystal structure for a series of samples with x 0, 0.1, 0.3, 0.5, 0.6, 0.7, 0.8, 0.9, and 1.0
# Zn-doped BSLCO (Bi
#                     2 Sr 2−x La x Cu 1−z Zn z O 6+δ ) single crystals with z of up to 2.2% for x = 0.50 and 0.66
# single crystals of Sr 2 Ru 1−x Ti x O 4 with
#                     concentrations of x = 0.1 and 0.2
#
# optimally doped (y=0.93) crystals having three different concentrations of Gd ions; x≃ 0.5%, x≃ 1%, and x≃ 3%
# Nd 1:85 Ce 0:15 CuO 4 and Nd 2 CuO 4 have been grown by molecular beam epitaxy (MBE) on (001) SrTiO 3 substrates
# Bi 2 Sr 2 Ca 1−x Er x Cu 2 O 8 , single crystals for x=0, 0.1, 0.5
#                     and 1.0
#
# slightly overdoped
#                         Bi 2 Sr 2 CaCu 2 O 8-x (Bi2212) single crystals
#
#
# me_method
#
# tcValue
# 77
#                     K
#
# up
#                         to ~3.8 K
#
#
#                     170 K
#
# 203
#                     K
#
# 5.0
#                     K
#
#
#                     43 K
#
# 18 ∼
#                         30 K
#
#
#                             exceeds 45K
#
#
#                         above 30 K
#
# 8.6
#                             K
#
#
#                         5.2
#
# above the boiling point of liquid nitrogen
#
#                         4.3 K
#
#
# pressure
#
#                         ambient pressure
#
# high
#                         pressures
#
# 0, 1.0,
#                         1.58 and 2.1 GPa
#
#
#                             up to 19 GPa

# %% [markdown]
# # Label summary
#
# In this section we analise each label and we output
#  - top terms
#  - the aggregation of similar terms using soft-matching

# %%
def plot_top_10(label, statistics): 
    class_statistics = statistics[label]
    class_count = class_statistics['count']
    print("count: " + str(class_count))
    class_frequency = class_statistics['content_distribution']
           
    sorted_by_value = {k: v for k, v in sorted(class_frequency.items(), key=lambda item: item[1], reverse=True)}

    top_10 = {k:sorted_by_value[k] for k in list(sorted_by_value.keys())[0:10]}
    # print(json.dumps(top_10, indent=4))

    ## HISTOGRAM

    plt.rcdefaults()
    fig, ax = plt.subplots()

    items = list(top_10.values())
    keys = list(top_10.keys())

    ax.barh(keys, items , align='center')
    ax.set_yticklabels(keys)
    ax.invert_yaxis()  # labels read top-to-bottom
    ax.set_xlabel('Frequency')
    ax.set_title(label +' annotation values top terms')

    plt.show()

    
def aggregate_by_soft_matching(statistics, aggregated):

#     agg_statistics_soft_matching = aggregated[label]
#     print(json.dumps(agg_statistics_soft_matching, indent=4))

    delete = []
    for k, v in aggregated.items(): 
        if len(v) > 0: 
            for val in v:
                
                statistics[k] += statistics[val]
                statistics[val] = 0
                delete.append(val)

    # print(json.dumps(stat, indent=4))
    print("Aggregating " + str(len(delete)) + " elements")
    
    return statistics

# %% [markdown]
# ## Class
#
# the label `<class> `

# %%
import copy 
entities_statistics = copy.copy(result['entities_statistics'])
# print(json.dumps(entities_statistics['class'], indent=4))
# plot_top_10('class', entities_statistics)

content_distribution = entities_statistics["class"]['content_distribution']
aggregated_statistics = result['aggregated_statistics']["class"]
entities_statistics["class"]['content_distribution'] = aggregate_by_soft_matching(content_distribution, aggregated_statistics)

## TODO update count

# Aggregated statistics via soft-matching
# print(json.dumps(result, indent=4))

# with open("bao.json", 'w') as f:
#     json.dump(result, f, indent=4)

# print(json.dumps(entities_statistics["class"]['content_distribution'], indent=4))
plot_top_10("class", entities_statistics)

#print(json.dumps(entities_statistics["class"], indent=4))
# agg_statistics_soft_matching_inv_map = {v: k for k, v in agg_statistics_soft_matching.items()}
# print(json.dumps(agg_statistics_soft_matching_inv_map, indent=4))
# Out:
# Aggregating 139 elements
# count: 1917
# /var/folders/mk/scd8428n18jfgh3jdthbvpz00000gn/T/ipykernel_89212/1087991225.py:21: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(keys)

# %% [markdown]
# ## Material
#
# the label `<material> `

# %%
import copy
entities_statistics = copy.copy(result['entities_statistics'])

aggregated_statistics = result['aggregated_statistics']['material']
content_distribution = entities_statistics["material"]['content_distribution']
entities_statistics["material"]['content_distribution'] = aggregate_by_soft_matching(content_distribution, aggregated_statistics)

plot_top_10("material", entities_statistics)
# Out:
# Aggregating 896 elements
# count: 8592
# /var/folders/mk/scd8428n18jfgh3jdthbvpz00000gn/T/ipykernel_89212/1087991225.py:21: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(keys)

# %% [markdown]
# ## Class (from Materials) distribution

# %%
import copy
entities_statistics = copy.copy(result['entities_statistics'])

aggregated_statistics = result['aggregated_statistics']['material']
content_distribution = entities_statistics["material"]['content_distribution']
entities_statistics["material"]['content_distribution'] = aggregate_by_soft_matching(content_distribution, aggregated_statistics)
entities_statistics["material"]['content_distribution']
# plot_top_10("material", entities_statistics)
# Out:
# Aggregating 896 elements
# {'La2−xSrxCuO4': 8,
#  'HgBa2CuO 4+δ': 0,
#  'La 2−x Sr x CuO 4': 20,
#  'HgBa 2 CuO 4+δ': 2,
#  'La 2−x Sr x CuO 4 (LSCO) with x = 0.10, 0.15, 0.20, 0.22, 0.24': 1,
#  'HgBa 2 CuO 4+δ (Hg-1201) with δ = 0.10, 0.37': 1,
#  'Single-phase polycrystalline samples of LSCO': 1,
#  'x = 0.10': 0,
#  '0.15': 1,
#  '0.20': 1,
#  '0.22': 1,
#  '0.24': 1,
#  'x = 0.10 and 0.15': 0,
#  'Hg-1201': 23,
#  'LSCO': 155,
#  'x = p = 0.10, 0.15, 0.20, 0.22 and 0.24': 1,
#  'Tl 2 Ba 2 CuO 6+δ': 0,
#  'δ = 0.10 and 0.37': 1,
#  'δ = 0.10 and 0.37 in Hg-1201': 1,
#  'x = 0.24': 0,
#  'polycrystalline LSCO': 1,
#  'Hg-1201 powders': 1,
#  'δ = 0.154': 2,
#  'x = p < 0.19': 1,
#  'x = 0.19': 0,
#  '0.20 < x < 0.35': 1,
#  'x = 0.20, 0.22 and 0.24': 2,
#  'x = 0.20 and 0.22': 2,
#  'x = 0.27': 0,
#  'HgBa 2 Ca 2 Cu 3 O 8+δ': 1,
#  'single crystal LSCO with x = 0.15': 2,
#  'YBCO': 90,
#  'x = 0.10 LSCO': 1,
#  'La2−xSrxCuO4 (LSCO) with x = p = 0.10, 0.15, 0.20, 0.22 and 0.24': 2,
#  'HgBa2CuO 4+δ unoriented powders with δ = 0.10, 0.154 and 0.37 (p = 0.075, 0.17 and 0.22': 1,
#  'La2−xSrxCuO4 (LSCO)': 4,
#  'La2−xSrxCuO4 with x = p = 0.10, 0.15, 0.20, 0.22 and 0.24': 0,
#  'x = 0.22 and 0.24': 1,
#  'Bi 2 Sr 2−z La z CuO 6+δ single crystals': 0,
#  'Bi2Sr2−zLazCuO 6+δ (BSLCO) single crystals': 1,
#  'BSLCO': 36,
#  'YBa2Cu3Oy': 1,
#  'Tl2Ba2CuO 6+δ': 1,
#  'La 2−x Sr x CuO 4 (LSCO)': 0,
#  'La 2−x Ba x CuO 4 (LBCO)': 2,
#  'YBa 2 Cu 3 O y (YBCO)': 0,
#  'Bi 2 Sr 2 CaCu 2 O 8+δ (Bi-2212)': 0,
#  'Bi 2 Sr 2 CuO 6+δ (Bi-2201)': 0,
#  'Tl 2 Ba 2 CuO 6+δ (Tl-2201)': 0,
#  'Bi 2 Sr 2−z La z CuO 6+δ (BSLCO, or La-doped Bi2201)': 1,
#  'z ≃ 0.4': 1,
#  'BSLCO single crystals': 5,
#  '0.2 to 1.0': 1,
#  'optimally-doped BSLCO crystal': 2,
#  'Bi 2 Sr 2−z La z CuO 6+δ': 1,
#  'crystals with z from 0.23 to 1.02': 1,
#  'z=0.39': 2,
#  'BSLCO crystals': 12,
#  'BSLCO crys- tals for selected z values from 0.23 -1.02': 1,
#  'optimally- doped BSLCO': 0,
#  'Tl-2201': 0,
#  'LSCO (x=0.16)': 0,
#  'YBCO (y=6.93)': 1,
#  'BSLCO (z=0.39)': 1,
#  'y ≃ 6.7': 2,
#  'y ≃ 6.4)': 1,
#  'La concentration, z, of 0.73 corresponds to p ≃ 0.12': 1,
#  'z=0.84 to p ≃ 0.10': 1,
#  'z=1.0 to p ≃ 0.03': 1,
#  'p = 0.18, 0.16, 0.15, 0.14, 0.13, 0.12, 0.10, and 0.03': 1,
#  'z = 0.23, 0.39, 0.49, 0.51, 0.66, 0.73, 0.84, and 1.02': 1,
#  'z=0.84': 1,
#  'z ≃ 0.9 (which corresponds to p = 0.09 -0.10)': 1,
#  'Tl- 2201': 35,
#  'La2−xSrxCuO4 polycrystalline compounds with Sr concentration up to x=0.24': 1,
#  'YBa 2 Cu 3 O 6.5': 0,
#  'YBa 2 Cu 2 O over': 1,
#  'YBa 2 Cu 4 O 8': 0,
#  'Bi 2 Sr 2 CaCu 2 O 8': 8,
#  'YBa 2 Cu 3 O x': 0,
#  'YBa 2 Cu 3 CuO x': 2,
#  'x=0.15': 17,
#  'LSCO polycrystalline compounds with x=0.06−0.24': 1,
#  'x=0.24': 7,
#  'x=0.06 and 0.07': 1,
#  'La 1.76 Sr 0.24 CuO 4': 0,
#  'La 1.94 Sr 0.06 CuO 4': 0,
#  'La 1.93 Sr 0.07 CuO 4': 0,
#  'Sr contents up to x=0.17': 1,
#  'YBa2Cu3O 7−δ with δ= 0.0, 0.3 and 0.43': 1,
#  'HgBa2Can−1CunO 2n+2+δ (n = 1 and 3)': 1,
#  'slightly overdoped HgBa 2 CuO 4+δ (Hg-1201)': 1,
#  'slightly underdoped HgBa 2 Ca 2 Cu 3 O 8+δ (Hg-1223)': 1,
#  'YBa 2 Cu 3 O 7 (YBCO 7 ) 6': 1,
#  'deoxygenated (underdoped) pure YBa 2 Cu 3 O 7−δ': 1,
#  'orthorhombic 11 YBa 2 Cu 3 O 7−δ (which has two CuO 2 planes per unit cell as well as Cu-O chains) with δ = 0.0, 0.3 and 0.43': 1,
#  'tetragonal Hg-1201': 1,
#  'tetragonal Hg-1223': 1,
#  'YBCO 7': 6,
#  'YBCO 6.7': 0,
#  'YBCO 6.57': 8,
#  'δ = 0.0 bulk piece': 1,
#  'δ = 0.3 and 0.43': 0,
#  'δ = 0.0, 0.3 and 0.43': 3,
#  'δ = 0.0 and δ > 0.0': 1,
#  'δ = 0.43': 1,
#  'YBCO 6.95 single crystals': 1,
#  'YBa 2 Cu 3 O 7−δ': 0,
#  'Hg-1223': 7,
#  'YBa 2 (Cu 1−x Zn x ) 3 O 7 (x =0.02 and 0.03)': 2,
#  'YBa 2 Cu 3 O 7−δ (δ = 0.0, 0.3 and 0.43)': 2,
#  'Tl 2 Ba 2 CuO 6+δ (Tl- 2201) single crystals': 1,
#  'Bi-2212 single crystals': 7,
#  'YBa 2 Cu 3 O 7−δ crystals': 1,
#  'YBCO 6.95': 1,
#  'YBCO 6.6': 1,
#  'Bi-2212': 0,
#  'Ba 0.6 K 0.4 BiO 3 (BKBO)': 1,
#  'Tl-2201 25': 1,
#  'underdoped YBCO': 0,
#  'YBa 2 Cu 3 O 7−δ with δ = 0.0, 0.3 and 0.43': 0,
#  'YBCO7': 0,
#  'YBCO6.7': 3,
#  'YBCO6.57': 0,
#  'Bi 2 Sr 2 CuO 6': 11,
#  'Bi 2 Sr 2 CuO 6 single crystals': 0,
#  'Tl 2 Ba 2 CaCu 2 O 8': 1,
#  'Bi 2 Sr 2 Cu0 6 single crystals': 3,
#  'Sr 2 CuO 6': 1,
#  'Tl 2 Ba 2 CuO 6': 7,
#  'Bi2201 single crystals': 0,
#  'single-crystal YBa 2 Cu 4 O 8': 1,
#  'YBa2Cu4O8 (Y-124) single crystals': 1,
#  'YBa2Cu3O6+x (Y-123)': 2,
#  'Y-124': 19,
#  'Y-123': 0,
#  'Nd 2−x Ce x CuO 4 (Nd-214)': 1,
#  'Bi 2 Sr 2 CaCuO 8': 0,
#  'YBa 2 Cu 3 O 6+x (Y-123)': 3,
#  'La 2−x Sr x CuO 4 (La-214)': 1,
#  'un- doped, insulating Y-123 and La-214': 1,
#  'optimally-doped Y-123': 0,
#  'YBa 2 Cu 4 O 8 (Y-124)': 0,
#  'Y- 123': 57,
#  '(189 and 259) were grown in Al 2 O 3 crucibles': 1,
#  'third crystal (315), grown in Y 2 O 3': 1,
#  'spec- imen 315': 1,
#  '189 and 259': 2,
#  '315': 1,
#  'Nd- 214': 4,
#  'Y-124 crystals': 1,
#  'Al-doped crystals': 1,
#  'Al-free specimen 315': 1,
#  'spec- imen 259': 2,
#  'specimen 259': 0,
#  'un- twinned Y-123': 1,
#  'underdoped Y-123': 1,
#  'HgBa2CuO4+x': 2,
#  'optimally doped La 2−x Sr x CuO 4': 2,
#  'Tl 2 Ba 2 CuO 6+x': 0,
#  'nearly opti- mally doped HgBa 2 CuO 4+x': 1,
#  'slightly over- doped HgBa 2 CuO 4+x': 1,
#  'HgBa 2 CuO 4+x (Hg-1201)': 0,
#  'La 2−x Sr x CuO 4 (p = x = 0.10, 0.15, 0.20, 0.22 and 0.24)': 1,
#  'HgBa 2 CuO 4+x (x=0.10': 1,
#  'LSCO sin- gle crystals with x < 0.20': 1,
#  '0.14 < x < 0.20': 1,
#  'x = p < 0.20': 2,
#  'x = p ≥ 0.20': 0,
#  'x = 0.20': 0,
#  'overdoped Hg-1201': 1,
#  'p ∼ 0.09': 1,
#  '0.18': 1,
#  'Zn-Doped YBa 2 Cu 3 O 6.95': 2,
#  'Zn-doped single crystals of YBa2Cu3O6.95': 1,
#  'Zn-doped YBa 2 Cu 3 O 7−δ (YBCO)': 1,
#  'Zn substituted': 0,
#  'pure, 0.15%, 0.31% and 1% Zn-doped single crystals YBCO': 1,
#  'Zn-doped polycrystalline YBCO': 1,
#  'pure YBCO': 7,
#  'Zn-doped': 14,
#  'pure': 5,
#  '1%': 2,
#  'Pure and Zn-doped YBa 2 Cu 3 O 6.95 (optimally doped) single crystals': 1,
#  'Zn-doped YBCO crystal': 0,
#  'pure (0% Zn)': 1,
#  '1% Zn': 2,
#  'Zn doped': 1,
#  '0.15%, 0.31% and 1% Zn doped': 2,
#  'nominally pure': 3,
#  '1% Zn-doped': 0,
#  '0.31% Zn doping': 1,
#  '0.15% Zn dop- ing': 1,
#  'Zn-free': 6,
#  'optimally doped YBCO': 2,
#  '1%-Zn doped': 0,
#  '1%Zn': 2,
#  '0.31%Zn': 1,
#  'Zn- doped YBCO single crystals': 3,
#  'YBCO crystals': 0,
#  'YBa 2 Cu 3 O 6.95': 0,
#  '1% Zn doped YBCO': 1,
#  '1%Zn- doped': 0,
#  '1% Zn doped': 4,
#  'Gd 1−x Pr x Ba 2 Cu 3 O 7−y single crystals': 1,
#  'Al-free orthorhombic Gd1−xPrxBa2Cu3O7−y single crystals (0 ≤ x ≤ 1.0)': 1,
#  'Pr123': 0,
#  'Pr123 single crystals': 1,
#  'GdBa 2 Cu 3 O 7−y (Gd123)': 2,
#  'fully doped orthorhombic RBa 2 Cu 3 O 7−y (R=Y, rare earth)': 1,
#  'Gd 1−x Pr x Ba 2 Cu 3 O 7−y [(Gd-Pr)123]': 1,
#  '(Y-Pr)123': 1,
#  'Al-free single crystals with (0 ≤ x ≤ 1.0)': 1,
#  '(Y 0.4 Pr 0.6 )123 crystal': 1,
#  'pure Pr123': 1,
#  '(Gd 0.4 Pr 0.6 )123': 8,
#  '(Y 0.4 Pr 0.6 )123': 0,
#  '(Gd 0.4 Z 0.6 )123': 0,
#  'Pr-123': 12,
#  '(Y 0.4 Pr 0.6 )123 (B) single crystals': 1,
#  '(Z 0.4 Pr 0.6 )123': 0,
#  'Pr123 crystals': 1,
#  'YBa2Cu4O8': 1,
#  'underdoped YBa 2 Cu 4 O 8': 2,
#  'polycrystalline YBa 2 Cu 4 O 8': 1,
#  'YBa 2 Cu 4 O 8 powder': 1,
#  'YBa2Cu4O8 powder': 1,
#  'YBa 2 Cu 2 O 8': 11,
#  'oxygen-deficient, fluorine-free polycrystalline samples with nominal chemical formula NdFeAsO 1-y': 1,
#  'LaFeAs(O 1-x F x )': 10,
#  'LnFeAsO': 1,
#  'oxygen-deficient NdFeAsO 1-y': 2,
#  'NdFeAsO 1-y': 21,
#  'LaFeAsO 1-y': 1,
#  'NdFeAsO1−y': 1,
#  '(Ca,Na)Fe 2 As 2': 1,
#  '1-y=0.90, 0.85, 0.80, 0.75 and 0.70': 0,
#  'NdFeAsO': 2,
#  '1-y=0.90': 2,
#  'Nd 2 O 3': 2,
#  'FeAs': 6,
#  '1-y=0.85': 2,
#  '1-y=0.90 and 0.85': 1,
#  '1-y=0.85 and 0.80': 1,
#  '1-y=0.85, 0.80, 0.75 and 0.70': 5,
#  'NdAs': 1,
#  '1-y=0.75 and 0.70': 1,
#  '1-y=0.70': 2,
#  'Fe 2 O 3': 1,
#  'Fe': 1,
#  '1-y=0.80': 1,
#  '1-y*=0.94': 1,
#  'NdFeAsO 1-δ': 0,
#  'oxygen-deficient, fluorine-free NdFeAsO 1-y': 1,
#  'LSCO with x < 0.2': 1,
#  'x = 0.1 and 0.15': 23,
#  'x=0.1': 0,
#  'LSCO with x=0.1': 1,
#  'LSCO sample with x = 0.1 and 0.15': 1,
#  'x = 0.1)': 0,
#  'x=0.1 and 0.15': 0,
#  'x = 0.1': 62,
#  'x = 0.15': 0,
#  'polycrystalline LSCO with x=0.15': 1,
#  'LSCO sample with x=0.1': 1,
#  'overdoped Tl 2 Ba 2 CuO y (Tl-2201)': 0,
#  'overdoped Bi 2 Sr 2 CuO y (Bi-2201)': 1,
#  'Tl-2201 and Bi- 2201': 1,
#  'doped Bi 2 Sr 2 CaCu 2 O y (Bi-2212)': 1,
#  'YBa 2 Cu 3 O 7−δ (YBCO)': 0,
#  'LSCO crystals': 0,
#  'x=0.08 and 0.17': 1,
#  'Bi-2212 crystals': 0,
#  'LSCO (x=0.15)': 10,
#  'underdoped LSCO': 0,
#  'La 2-x Sr x CuO 4 x=0.08': 1,
#  'optimally-doped LSCO (x=0.15)': 2,
#  'underdoped LSCO (x=0.08)': 0,
#  'under-doped LSCO (x=0.08)': 3,
#  'LSCO (x=0.08)': 2,
#  'optimally-doped LSCO': 1,
#  'overdoped Tl-2201 and overdoped Bi-2201': 1,
#  'LSCO (x=0.17)': 0,
#  'overdoped Tl-2201 or Bi-2201': 1,
#  'Bi-2212, LSCO (x=0.17)': 1,
#  'Bi-2212 or under- doped LSCO': 1,
#  'Y 1−x Pr x Ba 2 Cu 3 O 7': 3,
#  'Y 1−x Pr x Ba 2 Cu 3 O 7 single crystal thin films': 1,
#  'Y 1 Ba 2 Cu 3 O 7−δ (YBCO)': 4,
#  'Y 1−x Pr x Ba 2 Cu 3 O 7 (YPrBCO)': 1,
#  'YPrBCO': 0,
#  'oxygen-deficient YBCO': 1,
#  'GaAs': 2,
#  'YPrBCO samples having Pr composition x = 0.0, 0.2, 0.3, 0.4, and 1.0': 1,
#  'Samples with 20% and 30% Pr': 1,
#  'The sample with 40% Pr': 1,
#  '20% Pr': 1,
#  'PrBCO': 8,
#  'fully oxygenated YBCO': 1,
#  'oxygen deprived (123)YBCO': 1,
#  'thin films of Y 1−x Pr x Ba 2 Cu 3 O 7': 1,
#  'x = 0 (squares), 0.2 (circles), 0.dotted curve), 0.4 (dash-dotted curve), and 1.0 (short-dashed curve)': 1,
#  'four Pr concentrations x = 0 (squares), 0.2 (circles), 0.3 (solid triangles), 0.4 (open triangles)': 1,
#  'x = 0.3': 9,
#  'x= 0, 0.2, 0.3, and 0.4 (solid, dashed, dotted, and dash-dotted curves)': 1,
#  'x = 0.0 (squares), 0.2 (circles), 0.3 (solid triangles), 0.4 (open triangles)': 1,
#  'x = 0 (squares), 0.2 (circles), and 0.4 (triangles)': 1,
#  'Zn-doped YBa 2 Cu 3 O 7−δ': 3,
#  'Zn-doped YBa2Cu3O 7−δ single crystals': 1,
#  'Zn-doped YBCO single crystals': 0,
#  'Zn-doped YBCO': 3,
#  'single crystals of YBa 2 (Cu 1−z Zn z ) 3 O 7−δ': 1,
#  'YBa 2 - (Cu 1−z Zn z ) 3 O y': 1,
#  'z=2.7%': 5,
#  'under- doped LSCO': 1,
#  'y=6.70 crystals with different z (2.7%, 2.3%, and 1.3%)': 1,
#  'y=6.70, z=2.7%': 0,
#  'y=6.70, z=2.3%': 5,
#  'z=2.3%': 2,
#  'z=2.3% sam- ple': 1,
#  'z=2.7% samples with y=6.70, 6.75, 6.80, and 6.83': 1,
#  'y=6.83': 0,
#  'y=6.80, z=2.7%': 2,
#  'z=2.7% samples with y=6.70': 1,
#  'z=2.3% samples with y=6.50, 6.60, and 6.70': 1,
#  'y=6.60': 1,
#  'Zn-doped YBCO crystals': 0,
#  'un- derdoped LSCO': 12,
#  'Eu 1−x K x Fe 2 As 2 with x= 0, 0.35, 0.45 and 0.5': 1,
#  'single crystalline EuFe 2 As 2': 1,
#  'x = 0.5': 8,
#  'AFe 2 As 2 (A: Ba, Sr, Eu or Ca)': 1,
#  'AFe 2 As 2': 69,
#  'EuFe 2 As 2': 9,
#  'EuFe 2 As 2 single crystals and Eu 0.5 K 0.5 Fe 2 As 2 polycrystals': 1,
#  'Eu 0.5 K 0.5 Fe 2 As 2': 6,
#  'EuFe 2 As 2 single crystals': 0,
#  'Eu 1−x K x Fe 2 As 2': 1,
#  'x= 0.35, 0.45 and 0.5': 0,
#  'x= 0.5': 0,
#  'of polycrystalline samples of Eu 1−x K x Fe 2 As 2': 1,
#  'x= 0.0, 0.45 and 0.5': 0,
#  'Eu 1−x K x Fe 2 As 2 samples with x = 0.35, 0.45 and 0.5': 1,
#  'x = 0.45': 0,
#  'x = 0.35 and 0.5': 0,
#  'Eu 0.55 K 0.45 Fe 2 As 2': 0,
#  'x= 0, 0.45 and 0.5': 4,
#  'x= 0.45 and 0.5': 0,
#  'SrFe 2 As 2': 0,
#  'RuSr 2 GdCu 2 O 8': 41,
#  'RuSr2GdCu2O8': 0,
#  'La 2−x Ba x CuO 4': 0,
#  'Sr 2 RuO 4': 23,
#  'SrRuO 3': 7,
#  '1212-type RuSr 2 GdCu 2 O 8': 1,
#  'RuO 2': 2,
#  'Zn-substituted RuSr 2 GdCu 1.94 Zn 0.06 O 8': 1,
#  'Y ↔ Gd cosubsti- tuted sample RuSr 2 Gd 0.9 Y 0.1 Cu 2 O 8': 1,
#  'RuSr2GdCu2O 8−δ': 1,
#  'strongly underdoped YBa 2 Cu 3 O 7−δ': 1,
#  'GdBa 2 Cu 3 O 7−δ': 17,
#  'RuSr2GdCu1.94Zn0.06O8': 1,
#  'Y ←→ Gd co- substituted RuSr2Gd0.9Y0.1Cu2O8': 1,
#  '10% Y ↔ Gd cosubstituted RuSr 2 Gd 0.9 Y 0.1 Cu 2 O 8': 1,
#  'pure RuSr 2 GdCu 2 O 8': 1,
#  'RuSr 2 Cu 1.94 Zn 0.06 O 8': 1,
#  'GdBa 2 Cu 3 O 7−δ (Gd-123)': 0,
#  'ErRh 4 B 4': 2,
#  'HoMo 6 S 8 20': 1,
#  'Y 9 Co 7': 1,
#  'Ru-1212': 17,
#  'RuSr 2 Gd 1−x RE x Cu 2 O 8': 1,
#  'T l 0.5 P b 0. 5 Sr 2 Ca 1−x Y x Cu 2 O 7 system (0.0 ≤ x ≤ 0.35)': 1,
#  'Hg 0.82 Re 0.18 Ba 2 Ca 2 Cu 3 O 8+δ': 1,
#  'T l 0.5 P b 0.5 Sr 2 Ca 1−x Y x Cu 2 O 7': 0,
#  'T l 0.5 P b 0. 5 Sr 2 Ca 1−x Y x Cu 2 O 7': 9,
#  'Bi2212': 13,
#  'YBa2(Cu1−zZnz)3O6.78 crystals with 0≤z≤0.013': 1,
#  'under- doped YBCO': 15,
#  'YBa 2 (Cu 1−z Zn z ) 3 O y crys- tals with y=6.78': 1,
#  'y=6.78': 0,
#  'pure crystals': 1,
#  'Zn-doped crystalline thin films': 1,
#  'pure and Zn-doped sam- ples': 1,
#  'overdoped Tl 2 Ba 2 CuO 6+δ (Tl-2201)': 2,
#  'pure and Zn- doped YBCO (y=6.78) crystals': 1,
#  'Underdoped La 2−x Sr x CuO 4': 6,
#  'underdoped La2−xSrxCuO4': 0,
#  'La1.87Sr0.13CuO4': 0,
#  'La1.86Sr0.14CuO4': 0,
#  'Bi 2 Sr 2 CaCu 2 O 8+δ (Bi221)': 0,
#  'YBa 2 Cu 3 O 7−δ (Y123)': 0,
#  'Y123': 9,
#  'YBa 2 Cu 4 O 4 (Y124)': 2,
#  'x = 0.17': 0,
#  'x = 0.34': 0,
#  'YBa 2 Cu 3 O 7−x (Y123)': 0,
#  'YBa 2 Cu 4 O 8 (Y124)': 0,
#  'slightly underdoped LSCO': 1,
#  'doped La 2 CuO 4−δ , thin films of LSCO': 1,
#  'La 1.87 Sr 0.13 CuO 4': 0,
#  'x = 0.14': 0,
#  'x = 0.13': 0,
#  'Sr x = 0.14': 1,
#  'underdoped La1.87Sr0.13CuO4': 1,
#  'La1.86Sr 0.14CuO4': 7,
#  'La 1.86 Sr 0.14 CuO 4 single crystal': 0,
#  'La 1.86 Sr 0.14 CuO 4': 0,
#  'YBCO 123 and 124': 1,
#  'under- doped La 2−x Sr x CuO 4': 0,
#  'Y124': 3,
#  'La 2−x Sr x CuO 4+δ films': 0,
#  'doped La 2 CuO 4+δ': 0,
#  'Tl2202': 1,
#  'BSCO': 1,
#  'Bi 2 Sr 2−x La x CuO 6': 1,
#  'Bi2Sr2−xLaxCuO6 crystals': 1,
#  'Bi 2 Sr 2 CuO 6 (Bi-2201)': 3,
#  'Bi-2201': 0,
#  'B-2201': 8,
#  'YBa 2 Cu 3 O 7 (YBCO)': 0,
#  'Bi 2 Sr 2 CaCu 2 O 8 (Bi- 2212)': 9,
#  'Bi 2 Sr 2−x La x CuO 6 with x≃0.4': 1,
#  'Bi-2201 crystals': 3,
#  'Bi 2 Sr 2−x La x CuO 6 (BSLCO)': 1,
#  'pure Bi-2201': 3,
#  '0.30': 1,
#  '0.44': 1,
#  '0.57': 1,
#  '0.66': 1,
#  'Bi- 2201': 1,
#  'x=0.44': 6,
#  'Bi 1.8 Sr 1.57 La 0.44 CuO 6+δ': 1,
#  'x=0.57 and 0.66': 0,
#  'x=0.30 and 0.24': 3,
#  'x=0.66': 0,
#  'x =0.57, 0.44, 0.30, and 0.24': 1,
#  'x=0.57': 2,
#  'x=0.30': 2,
#  'x=0.24, 0.44, 0.57, and 0.66': 1,
#  'Overdoped La 2-x Sr x CuO 4': 2,
#  'overdoped La 2-x Sr x CuO 4 films': 1,
#  'T\uf06c 2 Ba 2 CuO 6+δ': 1,
#  'underdoped YBa 2 Cu 3 O 7-δ (YBCO) films': 1,
#  'underdoped YBCO films': 0,
#  'La 2-x Sr x CuO 4 (LSCO)': 0,
#  'T\uf06c 2 Ba 2 CuO 6+δ (T\uf06c2201)': 1,
#  'T\uf06c2201': 6,
#  'x > 0.22': 1,
#  'La 2-x Sr x CuO 4 films': 4,
#  'x = 0.27 and 0.30': 0,
#  'overdoped LSCO crystal': 1,
#  'LSCO films': 3,
#  'LSCO powders': 3,
#  'T\uf06c2201 powders': 1,
#  'x ≤ 0.21': 1,
#  'x \uf0b3 0.24': 1,
#  'x = 0.30 film': 1,
#  'x \uf0bb 0.15': 1,
#  'x \uf0bb 0.03 and 0.30': 1,
#  'x \uf0bb 0.19': 1,
#  'overdoped T\uf06c2201': 2,
#  'under-and overdoped LSCO films': 1,
#  'underdoped Ca-YBCO thick film': 1,
#  'overdoped LSCO films': 0,
#  'Ca-doped YBCO': 1,
#  'overdoped LSCO': 0,
#  'underdoped LSCO films': 1,
#  '"thick" underdoped YBCO films': 1,
#  'La 2- x Sr x CuO 4 films: x = 0.06, 0.15, 0.21, 0.30': 2,
#  'La 2-x Sr x CuO 4 films: x = 0.06, 0.15, 0.21, 0.30': 0,
#  'overdoped LSCO film': 0,
#  'Ca-doped YBCO films': 1,
#  'underdoped Ca- YBCO films': 2,
#  'YBa2Cu3O 7−δ (YBCO)': 1,
#  'YBCO films': 0,
#  'YBCO thin films': 4,
#  'sample I': 1,
#  'La 1.78 Sr 0.22 Cu 1-x Ni x O 4': 0,
#  'L a 1.78 Sr 0.22 CuO 4': 8,
#  'Ni-doped': 8,
#  'La 1.78 Sr 0.22 CuO 4': 0,
#  'La 1.78 Sr 0.22 Cu 1-x Ni x O 4 with nominal x=0, 0.01, and 0.02': 2,
#  'x=0': 15,
#  '0.01': 1,
#  '0.02': 1,
#  'Sr 0.22 Cu 1-x Ni x O 4': 1,
#  'x=0, 0.01 and 0.02': 4,
#  'x=0.01': 8,
#  'x=0.01 and 0.02': 0,
#  'L a 1.78 Sr 0.22 Cu 1-x Ni x O 4': 4,
#  'x=0, 0.01, and 0.02': 0,
#  'x=0.02': 3,
#  'YBa 2 Cu 3 O 7-d': 1,
#  'La 1-x Sr x CuO 4': 17,
#  'La 1.78 Sr 0.22 Cu 1-x Ni x O 4 with x=0,0.01 and 0.02': 0,
#  'Sr 0.22 Cu 0.99 Ni 0.01 O 4': 1,
#  'La 1.78 Sr 0.22 Cu 0.99 Ni 0.01 O 4': 1,
#  'Under-doped La 2−x Sr x CuO 4 with x = 0.063 -0.125': 1,
#  'x = 0.063, 0.07, 0.09, 0.10, 0.111 and 0.125\n                        ': 1,
#  'x = 1/4 2 (=0.0625) and 1/3 2 (=0.111)': 1,
#  'x < 0.02': 1,
#  '0.02 < x < 0.05': 1,
#  '0.05 < x < 0.26)': 1,
#  '0.26 < x < 0.6': 1,
#  'x > 0.6': 2,
#  '\n                    LSCO\n                ': 0,
#  'x =\n                    0.15': 4,
#  'La 2−x Sr x CuO 4 single crystals\n                ': 0,
#  'x = 0.063 -0.125': 2,
#  'LSCO\n                ': 0,
#  '(1-x/2)La 2 O 3 /xSrCO 3 /CuO in\n                    molar ratio with x = 0.063, 0.07, 0.09, 0.10, 0.111 and 0.125': 1,
#  'La 2 CuO 4': 24,
#  'La 1.91 Sr\n                    0.09 CuO 4 (x = 0.09)\n                ': 1,
#  'x = 0.063\n                    ': 11,
#  '\n                        x = 0.125': 1,
#  'x = 1/4 2 (=0.0625)\n                ': 1,
#  '1/3 2 (=0.111)': 1,
#  'x = 1/3 2': 1,
#  'x = 0.09 LSCO crystal': 1,
#  'La 1.91 Sr 0.09 CuO 4': 4,
#  'La 2−x Sr x CuO 4\n                ': 0,
#  'x\n                        = 1/3 2\n                    ': 1,
#  'La 1.875 Sr 0.125 CuO 4 crystal': 1,
#  'La 1.91 Sr 0.09 CuO 4(x = 0.09) crystal\n                ': 1,
#  'La 1.91 Sr 0.09 CuO 4 (x = 0.09)\n                    crystal': 1,
#  'La 2−x Sr x\n                    CuO 4 single crystals with various doping levels (x = 0.063 -0.125)': 1,
#  'Single-crystalline Sr 2 RuO 4': 1,
#  'Sr 2 RuO\n                        4': 1,
#  'Sr 2−y La y RuO 4': 1,
#  'overdoped Bi 2 Sr 2 CaCu 2 O 8+δ': 4,
#  'overdoped Bi2Sr2CaCu2O 8+δ': 1,
#  'Bi 2 Sr 2 CaCu 2 O 8+δ\n                        (Bi-2212)': 1,
#  '\n                    Bi-2212\n                ': 2,
#  'Single crystals of Bi-2212': 3,
#  'Bi-2212 crystal': 0,
#  'overdoped Bi-2212': 6,
#  'overdoped Bi-2212\n                ': 3,
#  'Bi-2212\n                ': 3,
#  'underdoped Bi-2212\n                ': 0,
#  'underdoped\n                    Bi-2212\n                ': 2,
#  '\n                    underdoped Bi-2212\n                ': 0,
#  'underdoped and\n                    overdoped Bi-2212\n                ': 1,
#  '\n                    overdoped Bi-2212\n                ': 2,
#  '\n                    over- doped Bi-2212': 2,
#  'overdoped\n                    Bi-2212\n                ': 0,
#  'underdoped Bi-2212': 2,
#  '"F-free" Single Crystals of CeOBiS 2': 1,
#  'F-free" CeOBiS2 single crystals': 0,
#  'CeOBiS2\n                    ': 0,
#  'non-doped CeOBiS2': 1,
#  '\n                    R(O,F)BiS2 (R: La, Ce, Pr, Nd, Yb)\n                ': 1,
#  'ROBiS2': 1,
#  'Rn(O,F)FeAs (Rn: rare earth elements)\n                    ': 1,
#  'Bi(O,F)BiS2': 1,
#  '\n                        La(O,F)BiCh2 (Ch = S, Se)\n                    ': 1,
#  'Ce(O,F)BiS2': 16,
#  'CeOBiS2': 27,
#  '\n                    CeOBiS2\n                ': 0,
#  '"F-free" CeOBiS2 single crystals\n                ': 1,
#  'Single crystals of CeOBiS2': 1,
#  '"F-free" CeOBiS2 single crystals': 3,
#  'CeOBiS2 single crystals': 0,
#  '"F-doped" CeOBiS2 crystals': 1,
#  '\n                    Ce(O0.73F0.27)BiS2\n                ': 1,
#  '"F-free" CeOBiS2 and "F-doped" Ce(O0.73F0.27)BiS2\n                    crystals\n                ': 1,
#  'Ce(O,F)BiS2\n                ': 5,
#  'CeOBiS2 crystals': 2,
#  'La(O,F)BiS2': 2,
#  'Ce(O,F)BiS2 single\n                    crystals\n                ': 2,
#  'single crystals of CeOBiS2 and Ce(O,F)BiS2': 1,
#  '\n                    Ce(O,F)BiS2': 1,
#  '\n                    "F-free" CeOBiS2\n                ': 2,
#  'CeOBiS2\n                ': 0,
#  'Ce(O,F)SbS2': 0,
#  'EuFBiS2': 0,
#  'F-doped single crystals': 1,
#  'F-doped crystal': 1,
#  'F-free CeOBiS2 single crystals': 0,
#  'CeOBi0.96S2': 1,
#  '\n                        Ce(O,F)BiS2\n                    ': 1,
#  'Ce(O,F)BiS2 single crystals': 3,
#  'single\n                    crystals of CeOBiS2 and Ce(O,F)BiS2': 1,
#  'CeOBiS2 single\n                    crystals\n                ': 0,
#  'CeOBiS2 single crystals\n                ': 2,
#  'single crystals of\n                    CeOBiS2': 1,
#  'metallic hydrogen': 1,
#  'hydrogen': 3,
#  'sulfur hydride': 9,
#  'sulfur\n                        deuteride\n                    ': 1,
#  'H 3 S': 2,
#  'H 2 S\n                        ': 2,
#  'MgB 2\n                ': 14,
#  '\n                    metallic hydrogen\n                ': 1,
#  'molecular hydrogen': 1,
#  'pure hydrogen': 3,
#  'SiH 4': 1,
#  'SnH 4': 1,
#  'H 2 S': 15,
#  'hydrogen sulphide': 0,
#  'sulfur': 2,
#  'D 2 S': 3,
#  'sulfur deuteride': 7,
#  'decomposition of H 2 S': 1,
#  'elemental sulfur': 2,
#  '3H 2 S R\n                        H 6 S 1 2S\n                    ': 1,
#  '2H 2 S R H 4 S 1 S': 1,
#  'H\n                    2 S R H 2 1 S\n                ': 1,
#  '(H 2 S) 2 H 2': 1,
#  'H 3 S\n                    ': 1,
#  'H 3 S\n                ': 0,
#  'MgB 2': 95,
#  'H 2\n                    S': 0,
#  'YBa 2 Cu 3 O 7': 0,
#  'Nb 3\n                        Sn\n                    ': 0,
#  'pure sulfur': 1,
#  'sulfur hydride\n                ': 2,
#  '\n                    sulfur hydride\n                ': 1,
#  'Bi-2223': 0,
#  'Sr 0.9 La 0.1 CuO 2': 0,
#  'doped Sr 0.9 La 0.1 CuO 2': 2,
#  '͑Y 12x Ca x ͒Ba 2 Cu 3 O 72d\n                    ': 1,
#  'Nd 1.85 Ce 0.15 CuO 42d': 0,
#  'Pr 1.85 Ce 0.15\n                    CuO 42d\n                ': 1,
#  'Sr 12x L x CuO 2 (L La, Gd, Sm)': 1,
#  'Sr\n                    0.9 La 0.1 CuO 2\n                ': 1,
#  'Sr\n                    0.9 La 0.1 CuO 2 (SLCO)': 1,
#  'Sr 0.9 La 0.1 ͑Cu 0.99 Zn 0.01 ͒O 2 (1%\n                    Zn-SLCO)': 1,
#  'Sr 0.9 La 0.1 ͑Cu 0.99 Ni 0.01 ͒O 2 (1% Ni-SLCO)': 1,
#  '\n                    SLCO\n                ': 0,
#  '1% Zn-SLCO': 4,
#  '1%\n                    Ni-SLCO': 0,
#  '1% Ni': 1,
#  '2% Ni': 1,
#  'SLCO': 16,
#  'pure SLCO': 4,
#  '\n                    SLCO': 5,
#  '\n                        SLCO': 0,
#  '1%\n                    Zn-SLCO': 0,
#  'YBa 2 ͑Cu 0.9934 Zn 0.0026 Mg 0.004 ͒ 3 O 6.9 single crystal': 1,
#  '1% Ni-SLCO': 7,
#  '1%\n                    Ni-SLCO\n                ': 0,
#  'Bi 2 Sr 2 Ca͑Cu 12x Ni x ͒ 2 O 81x': 1,
#  'YBa 2 ͑Cu 0.9934 Zn 0.0026 Mg 0.004 ͒ 3 O 6.9': 1,
#  'pure YBa 2 Cu 3 O 6.9': 1,
#  'Sr 12x L x CuO 2 (L\n                    La, Gd, Sm)': 1,
#  '\n                    doped YBa 2 Cu 3 O 72d\n                ': 1,
#  'pure\n                    SLCO': 0,
#  'Na 0.32 CoO 2': 0,
#  'NaOH': 2,
#  'Na 0.22 H 0.1 CoO 2 • 0.85H 2 O': 4,
#  'Na x CoO 2 • yH 2 O (x ≈ 0.35, y ≈ 1.3)': 0,
#  'Na 0.7 CoO 2 polycrystals': 1,
#  'Na 0.74 CoO 2': 1,
#  'Na 0.7 CoO 2': 0,
#  'Na x CoO 2 (0.25 < x < 0.7)': 1,
#  'Na 0.7 CoO\n                    2\n                ': 1,
#  'Na x CoO 2': 18,
#  'x=0.32': 1,
#  'Na 0.32 CoO 2\n                    ': 1,
#  'Na 0.32\n                    CoO 2\n                ': 0,
#  'Co 3 O 4': 6,
#  'Co\n                    3 O 4\n                ': 0,
#  'Co 3 O 4\n                ': 2,
#  'Na 0.22 H\n                    0.1 CoO 2 • 0.85H 2 O': 1,
#  'Na 0.32 CoO 2 • 2.3H 2 O': 0,
#  'Na 0.22 H 0.1 CoO 2 • 0.85H\n                    2 O': 1,
#  'Na0.22 H 0.1 CoO 2 • 0.85H 2 O': 0,
#  'Na 0.22 H 0.1 CoO 2 •0.85H 2 O': 0,
#  'Na 0.32 CoO 2 • 2.3H 2 O\n                ': 0,
#  '\n                    Na 0.22 H 0.1 CoO 2 • 0.85H 2 O\n                ': 1,
#  'Na 0.32 CoO 2 • 2.3H 2\n                        O': 1,
#  'Na 0.22 H 0.1 CoO 2 •\n                    0.85H 2 O\n                ': 1,
#  'Na\n                    0.32 CoO 2\n                ': 3,
#  'CaC 6': 18,
#  'CaC6\n                    ': 1,
#  '\n                            CaC6': 1,
#  'graphite intercalated with Ca , Yb\n                ': 1,
#  'Sr': 1,
#  'Ca-intercalated graphite': 1,
#  'CaC 6\n                ': 0,
#  'pyrolytic graphite': 1,
#  'CaC 6\n                    ': 0,
#  'AOs 2 O 6': 6,
#  'AOs 2 O 6 (A = Cs, Rb, K)': 3,
#  'A = Cs, Rb and\n                            K': 1,
#  'A\n                            = Rb and K\n                        ': 1,
#  'A = Cs': 1,
#  'KOs 2 O 6': 40,
#  'RbOs 2 O 6\n                ': 0,
#  'KOs 2 O 6\n                ': 0,
#  'CsOs 2 O 6': 11,
#  'RbOs 2 O 6': 74,
#  'Cs': 7,
#  'Rb': 3,
#  'Cs\n                ': 0,
#  'K': 6,
#  'RbOs 2 O 6\n                    ': 0,
#  'KOs 2\n                    O 6\n                ': 0,
#  'Cd 2 Os 2 O 7': 12,
#  'CsOs 2 O 6\n                ': 0,
#  '\n                    β-pyrochlore 4 oxides\n                ': 1,
#  'CeCu 2 Ge 2': 3,
#  'Cd 2\n                        Re 2 O 7\n                    ': 1,
#  'AOs 2 O\n                    6\n                ': 6,
#  'K\n                ': 0,
#  '\n                    RbOs 2 O 6\n                ': 0,
#  'RbOs\n                    2 O 6\n                ': 0,
#  'Cd 2 Re 2 O 7': 44,
#  'A = Cs, Rb and K': 1,
#  'CeCoIn 5−x Sn x': 15,
#  'Sn-substituted CeCoIn 5\n                    ': 1,
#  'x ≤ 0.12': 5,
#  'CeCoIn 5−x\n                            Sn x\n                        ': 1,
#  'pure CeCoIn 5\n                    ': 1,
#  'CeIn 3': 3,
#  'CePd 2 Si 2\n                    ': 2,
#  'URu 2 Si 2': 4,
#  'PrFe 4 P 12\n                    ': 1,
#  'Sr 3 Ru 2 O 7': 2,
#  'MnSi': 1,
#  'CeCoIn 5': 22,
#  'CeCoIn 5\n                ': 15,
#  'Single crystals of CeCoIn 5−y Sn y (0 ≤ y ≤ 0.4)': 1,
#  'Sn concentration x ∼ 0.6y': 1,
#  'CeCoIn 5−x Sn x for x ≤ 0.12': 1,
#  'LaCoIn 5': 1,
#  'x = 0.03, 0.06, and\n                    0.12': 1,
#  'x = 0, 0.03, 0.06': 2,
#  'x = 0.12': 0,
#  'U 0.2 Y 0.8 Pd 3': 1,
#  'YbRh 2 Si 2\n                ': 1,
#  'CeCoIn 5−x Sn x\n                    for x = 0.03\n                ': 1,
#  'x = 0.03 (x = 0.12)\n                ': 1,
#  '\n                        CeRhIn 5\n                    ': 0,
#  'CeCoIn 5−x Sn x\n                ': 1,
#  'x = 0\n                    (not shown) , 0.03, and 0.06': 1,
#  'CeCoIn 5−x Sn x\n                    for x ≤ 0.12': 1,
#  'x ≤ 0.12)': 0,
#  'x = 0 [21], 0.03, and 0.12': 1,
#  'CeCoIn 5−x Sn x (x ≤ 0.12)': 1,
#  'CeCoIn 5\n                    ': 0,
#  '\n                    CePd 2 Si 2\n                ': 2,
#  'x = 0.03': 0,
#  'x = 0.06': 0,
#  'x = 0 [15], 0.03, 0.06': 1,
#  '\n                    CeCoIn 5−x Sn x for x = 0.03\n                ': 1,
#  'x\n                    = 0.12': 1,
#  'x = 0\n                ': 22,
#  'CeIrIn 5': 17,
#  'CeIrIn5\n                    ': 0,
#  'Ir\n                    ': 0,
#  'Rh': 2,
#  'CeIrIn5': 0,
#  'CeMIn 5 (M =\n                    Co, Rh, and Ir)\n                ': 1,
#  'CeRhIn 5': 3,
#  'Ir': 2,
#  'CeIrIn 5\n                ': 0,
#  'CeRhIrIn 5': 1,
#  'CeRh 0.5 Ir 0.5 In 5': 1,
#  'Single crystals of CeIrIn 5': 1,
#  'BeCu': 1,
#  'Daphne oil': 1,
#  'Sn': 2,
#  'LaIrIn 5': 4,
#  'LaIrIn\n                    5\n                ': 0,
#  'CeIrIn 5\n                    ': 2,
#  'CeRhIn\n                    5\n                ': 0,
#  'CeIrIn\n                    5\n                ': 3,
#  '\n                        CeCoIn 5': 1,
#  'CeCu 2 X 2 (X=Si and Ge)': 1,
#  'CeCu 2 (Si\n                    1−x Ge x ) 2\n                ': 1,
#  'CeIrIn\n                        5\n                    ': 0,
#  'CeCu 2 Si 2': 7,
#  'LaIrIn5': 0,
#  'LaIrIn5\n                ': 1,
#  '\n                    LaIrIn5': 1,
#  'CeCoIn5': 0,
#  'RbOs 2 O 6\n                        ': 1,
#  '\n                    CdRe 2 O 7\n                ': 0,
#  'CsOs\n                    2 O 6\n                ': 0,
#  'CdRe 2 O 7': 1,
#  'RbOs 2 O 6 powder': 2,
#  'Fluorient FC77': 1,
#  'In': 1,
#  'In\n                ': 1,
#  'RbOs 2 O\n                    6\n                ': 0,
#  'underdoped Bi 2 Sr 2 CaCu 2 O 8+δ': 0,
#  'under- doped Bi2Sr2CaCu2O 8+δ': 1,
#  'underdoped Bi 2 Sr 2 CaCu 2 O 8+δ\n                ': 1,
#  'Sr 2 CaCu 2 O 8+δ crystals': 2,
#  'doped Zr 5 Ge 3\n                ': 1,
#  'doped Zr 5 Ge 3': 2,
#  'Zr 5 Ge 3−x Ru x': 2,
#  'Zr 5 Ge 3−x Pt x': 7,
#  'Mn 5 Si 3': 1,
#  'Ta 5 Ge 3': 1,
#  'Nb 5 Si\n                    3\n                ': 1,
#  'Zr 5 X 3 (X\uf0a0=\uf0a0Sb, Pb, Sn, Ge, Si and Al)': 1,
#  'Zr 5 Sb 3': 1,
#  'Ru-doped Zr 5 Sb\n                        3\n                    ': 1,
#  'Hf 5 Sb 3': 1,
#  'Ru-doped Zr 5 Ge\n                    3\n                ': 1,
#  'Zr 5 Ge 3': 16,
#  'Pt doped Zr 5 Ge 3−x Pt\n                    x\n                ': 1,
#  'Pd, or Ir doping\n                ': 1,
#  'Zr 5 Ge 3\n                    ': 0,
#  'Zr 5 Sb 3−x Ru\n                        x and Hf 5 Sb 3−x Ru x\n                    ': 1,
#  'Ru doping': 1,
#  'Pd': 1,
#  'Pt': 2,
#  'Ru': 2,
#  'Zr 5 Ir 3': 1,
#  'Zr 5 Pt 3': 6,
#  'Zr 5 Ge 2.5 Pd 0.5\n                ': 6,
#  'x\uf0a0=\uf0a00.5': 1,
#  'Zr 5 Ge 3−x M x (M\uf0a0=\uf0a0Pd, Ir, and Pt)\n                    ': 1,
#  'Zr 5 Ge 2.5 Pt\n                    0.5\n                ': 0,
#  'Zr-Ir alloy': 1,
#  'Pt doping': 3,
#  'Ge site doped sample Zr 5 Ge 2.5 Pt 0.5\n                ': 1,
#  'Zr site Zr 4.5 Pt 0.5 Ge 3': 1,
#  'Zr 5 Ge 3 Pt 0.5\n                    ': 2,
#  'Zr 5 Sb 3−x Ru x': 2,
#  'Hf 5 Sb\n                        3−x Ru x\n                    ': 1,
#  'Zr 5 Ge 3\n                ': 6,
#  'Zr 5 Ge 3−x Ru x\n                    ': 1,
#  'x\uf0a0=\uf0a00, 0.2, 0.5, 1.0 and 1.2': 1,
#  '0%, 6.7%, 16.7%, 33.3%, and 40%': 1,
#  '\n                    x = 1\n                ': 0,
#  'Zr 5 Ge 2 Pt': 3,
#  'Pt doped': 1,
#  'Pt\n                        indeed doped at the Ge site': 1,
#  'x\uf0a0=\uf0a01': 1,
#  'Pt doped\n                ': 2,
#  'Zr 5 Ge 2.8\n                        Pt 0.2\n                    ': 1,
#  'Zr\n                        5 Ge 2 Pt': 1,
#  'Zr 5 Ge 2.8\n                    Pt 0.2\n                ': 0,
#  'Zr 5 Ge 2.5 Pt 0.5': 6,
#  'Zr 5 Ge 3−x Pt x\n                    ': 0,
#  'Zr 5 Ge 2.5 Pt 0.5\n                ': 0,
#  'Pt doped Zr 5 Ge 3−x Pt x': 1,
#  'x\uf0a0>\uf0a01': 1,
#  'x = 3': 1,
#  'Zr 5 Ge 2.5 Pt 0.5\n                    ': 0,
#  'Zr 5\n                    Sb 3\n                ': 0,
#  'Zr 5 Ge\n                    2.5 Pt 0.5\n                ': 2,
#  'Zr 5 Ge 2.5 Ru 0.5': 0,
#  'Zr 5\n                    Ge 3\n                ': 2,
#  'Pt\n                        doped Zr 5 Ge 3\n                    ': 1,
#  'doping with Y': 1,
#  '\n                        doping with Cr at the Zr site': 1,
#  'Y 5 Ge 3': 1,
#  'Cr doping': 1,
#  'Cr 5 Ge 3': 1,
#  'Zr 5−x Y x Ge 3 (x\uf0a0=\uf0a01)': 0,
#  'Zr 5−x\n                    Cr x Ge 3 (x\uf0a0=\uf0a01)': 1,
#  'Mn 5 Si 3\n                ': 1,
#  'ZrCrGe 2': 2,
#  'Y and Cr doping': 1,
#  'Pt and Ru doping': 1,
#  'Ru or Pt dopants': 1,
#  'Hf 5 Sb 3−x Ru x\n                ': 1,
#  'Zr 5 Ge 2.5 Ir 0.5': 2,
#  'Zr 5 Ge 2.5 Pd\n                    0.5\n                ': 3,
#  'ZrGe 2': 1,
#  'ZrPd': 1,
#  'doped Zr 5 Ge 3−x M x': 1,
#  'Pt doped\n                    ': 0,
#  'Pt\n                    ': 0,
#  'Pt doped Zr 5 Ge 3−x Pt x\n                ': 1,
#  'x\uf0a0=\uf0a00, 0.2, 0.5 and 1.0': 1,
#  'Zr 5\n                        Ge 3−x Pt x': 1,
#  'x\uf0a0<\uf0a00.2': 1,
#  'Zr 5−x Y x Ge 3\n                    (x\uf0a0=\uf0a01)': 1,
#  'Zr 5−x Cr x Ge 3 (x\uf0a0=\uf0a01)': 2,
#  'Cr': 1,
#  'Y': 1,
#  'La 2-x Pr x Ca y Ba 2 Cu 4+y O z (x = 0.1 -0.5, y = 2x)': 1,
#  'La 2-x Pr x Ca y Ba 2 Cu 4+y O z (LaPrCaBCO)': 1,
#  'LaPrCaBCO samples for x = 0.1 -0.5': 1,
#  'x = 0.5\n                        (La-2125 stoichiometry)': 1,
#  'LaPrCaBCO': 5,
#  'La-2125': 2,
#  'La 2-x R x Ca y Ba 2 Cu 4+y O z (La-2125)': 1,
#  'x =\n                    0.5\n                ': 0,
#  'La 2 Ba\n                    2 Cu 4 O z (x = 0.0)': 1,
#  'x = 0.5 (La-2125)': 1,
#  'LaPrCaBCO series (x = 0.1 -0.5)': 1,
#  'LaPrCaBCO (x = 0.1 -0.5)\n                ': 1,
#  'La-123': 1,
#  'La-2125\n                ': 1,
#  'La 2-x Pr x Ca y Ba 2 Cu 4+y O z': 1,
#  'R = Nd, Dy and Pr in La 2-x R x Ca y Ba 2 Cu 4+y O z': 1,
#  'La 2-x Pr x Ca y Ba 2 Cu 4+y O z compounds for x = 0.1 -0.5 (y = 2x)': 1,
#  'Ba 1−x K x BiO 3': 0,
#  'Ba1−xKxBiO3': 2,
#  'Sm 2−x Ce x CuO 4': 1,
#  'Bi 2 Sr 2 CuO y\n                    ': 1,
#  'YBa 2 (Cu 1−x Zn x )O 7−δ': 1,
#  'non\n                    magnetic Ba 1−x K x BiO 3\n                ': 1,
#  'Ba 1−x K x BiO 3\n                ': 1,
#  'single-crystalline Ba 1−x K x BiO 3': 1,
#  'Ba 1−x K x BiO\n                        3 single crystal\n                    ': 1,
#  'Ba 1−x K x\n                        BiO 3\n                    ': 2,
#  'Ba 1−x K x\n                    BiO 3\n                ': 0,
#  'Ba 1−x K x BiO 3 film': 1,
#  'Ba\n                    1−x K x BiO 3 crystal\n                ': 1,
#  'Ba1−xKxBiO3 single crystal': 1,
#  'Ba1−xKxBiO3-Ag': 1,
#  'Bi 2 Sr 2−x La x CuO 6+δ': 0,
#  'Bi2Sr2−xLaxCuO 6+δ (x=0.65, 0.40, 0.25, 0.15 and 0)': 1,
#  'x ∼ 0.05\n                    ': 0,
#  'x=0.40\n                    ': 0,
#  'Bi 2 Sr 2−x La x CuO 6+δ\n                ': 1,
#  'x=0.40, 0.25, 0.15 and 0': 1,
#  'Bi2Sr2−xLaxCuO 6+δ': 1,
#  'Bi 2 Sr 2 CuO 6.36': 0,
#  'x=0.4': 0,
#  'x ≥0.15': 1,
#  'x=0.65': 0,
#  'x=0.35': 1,
#  'x ≤0.15': 1,
#  'x ≥0.25': 1,
#  'x=0.40': 2,
#  'x ≤0.40': 2,
#  'x opt =0.40': 1,
#  'around x=0.05': 1,
#  'Bi 2 Sr 1.6 La 0.4 CuO 6+δ': 2,
#  'CeRh 1−x Ir x In 5': 1,
#  '(x=0, 0.15, 0.25, 0.40 and 0.65)': 1,
#  'x ∼0.05': 1,
#  'Bi2Sr1.6La0.4CuO 6+δ': 1,
#  'Bi2Sr2CuO 6+δ\n                ': 1,
#  'x=0\n                ': 0,
#  'Bi2Sr2−xLaxCuO\n                    6+δ': 1,
#  'Na x CoO 2 • yH 2 O': 0,
#  'Na x CoO 2 • yH 2 O\n                    ': 0,
#  'Na 0.5 CoO 2': 23,
#  'Na x CoO 2 • yH 2 O\n                ': 6,
#  'Na 0.7 CoO 2\n                ': 3,
#  '\n                    Na x CoO 2 (x ∼ 0.4)': 1,
#  'Na x CoO 2\n                ': 0,
#  'Na': 6,
#  'x ≤ 0.35': 2,
#  'NaOH\n                ': 3,
#  'La 2−x Ce x CuO 4−y': 1,
#  'Pr 2−x Ce x CuO 4−y': 2,
#  '\n                        Pr2−xCexCuO4−y\n                    ': 1,
#  'La2−xCexCuO4−y films': 1,
#  'doped Pr 2−x Ce x CuO 4−y (PCCO)': 1,
#  'Nd 2−x Ce x CuO 4−y (NCCO)\n                    ': 1,
#  'PCCO\n                ': 3,
#  'La 2−x Ce x CuO 4−y (LCCO) films': 1,
#  'LCCO film': 1,
#  'x = 0.112': 1,
#  'PCCO film\n                ': 0,
#  'x = 0.145': 4,
#  'PCCO film': 7,
#  'PCCO': 18,
#  'LCCO': 8,
#  'overdoped LCCO film': 4,
#  'LCCO crystals': 9,
#  'LCCO films\n                ': 3,
#  'overdoped PCCO': 0,
#  'overdoped LCCO': 9,
#  'underdoped PCCO and LCCO': 1,
#  'underdoped PCCO': 0,
#  'underdoped PCCO\n                ': 1,
#  'PCCO films': 0,
#  'overdoped PCCO and LCCO films': 1,
#  'Optimally doped LCCO': 4,
#  '\n                            Sr0.9La0.1CuO2': 1,
#  'R 2−x Ce x CuO 4−δ (R= Nd, Sm, Pr)': 1,
#  '(Sr,Ln)CuO 2 (Ln=La, Sm, Nd, Gd)': 1,
#  'Sr 0.9 La 0.1 CuO 2\n                ': 1,
#  'Sr 0.9 La 0.1 CuO\n                    2\n                ': 1,
#  'Sr 0.9 La 0.1 CuO 2 (SLCO)': 1,
#  'SLCO\n                ': 0,
#  'n-type SLCO': 1,
#  'Nd 1.85 Ce 0.15 CuO 4 (NCCO) single\n                    crystals\n                ': 2,
#  'n-type NCCO': 1,
#  'single crystals of SLCO': 0,
#  'SLCO\n                    ': 1,
#  'Sr0.9La0.1CuO2': 11,
#  '\n                    Sr0.9La0.1CuO2': 1,
#  'Sr0.9La0.1CuO2 (SLCO)': 1,
#  'Nd1.85Ce0.15CuO 4−δ (NCCO) single\n                    crys- tals\n                ': 0,
#  'CoSr 2 (Y 1-x Ca x )Cu 2 O 7+δ': 6,
#  'CoSr 2 (Y 1-x Ca x )Cu 2 O 7+δ (Co-1212)': 1,
#  'x = 0.4': 23,
#  '-0.03 ≤ δ ≤ 0.00': 1,
#  'x = 0.3\n                    ': 0,
#  'CuBa 2 YCu 2 O 7-δ\n                    (Cu-1212)': 1,
#  'Tl-1212': 2,
#  '\n                        Ru-1212\n                    ': 0,
#  'Hg-1212': 2,
#  'Ga-1212': 1,
#  'Al-1212': 1,
#  'Co-1212': 9,
#  ...}

# %% [markdown]
# ## Critical temperature expressions
#
# the label `<tc>`

# %%
import copy
entities_statistics = copy.copy(result['entities_statistics'])

aggregated_statistics = result['aggregated_statistics']['tc']
content_distribution = entities_statistics["tc"]['content_distribution']
#entities_statistics["tc"]['content_distribution'] = aggregate_by_soft_matching(content_distribution, aggregated_statistics)

plot_top_10("tc", entities_statistics)
# Out:
# count: 4380
# /var/folders/mk/scd8428n18jfgh3jdthbvpz00000gn/T/ipykernel_89212/1087991225.py:21: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(keys)

# %% [markdown]
# ## Measurement Methods
#
# the label `<me_methods>`

# %%
import copy
entities_statistics = copy.copy(result['entities_statistics'])

name = 'me_method'
aggregated_statistics = result['aggregated_statistics'][name]
content_distribution = entities_statistics[name]['content_distribution']
entities_statistics[name]['content_distribution'] = aggregate_by_soft_matching(content_distribution, aggregated_statistics)

plot_top_10(name, entities_statistics)
# Out:
# Aggregating 126 elements
# count: 2238
# /var/folders/mk/scd8428n18jfgh3jdthbvpz00000gn/T/ipykernel_89212/1087991225.py:21: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(keys)

# %%
local_distribution = copy.copy(entities_statistics[name]['content_distribution'])

classes = {
    "specific heat": {
        "total":0, 
        "values": [],
        "names": ["heat", "therm"]
    }, 
    "magnetic susceptibility": {
        "total":0, 
        "values": [],
        "names": ["susceptibilit"]
    }, 
    "resistivity": {
        "total":0, 
        "values": [],
        "names": ["resistivit", "resistance", "electrical"]        
    },
    "magnetisation": {
        "total":0, 
        "values": [],
        "names": ["magneti"]        
    },
    "empirical calculation": {
        "total":0, 
        "values": [],
        "names": ["calcula", "predict", "theor"]        
    }
    
}

not_assigned = []
assigned = False
for key in local_distribution.keys(): 
    for key_class, value in classes.items():
        for names in value['names']: 
            if names in str.lower(key): 
                classes[key_class]["values"].append(key_class)
                classes[key_class]["total"] += local_distribution[key]
                assigned = True
                break
        if assigned:
            break
        
                
    if assigned == False: 
        not_assigned.append(key)
    else: 
        assigned = False
            
            

## HISTOGRAM

plt.rcdefaults()
fig, ax = plt.subplots()

items = [classes[c]["total"] for c in classes]
keys = list(classes.keys())

ax.barh(keys, items , align='center')
ax.set_yticklabels(keys)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Frequency')
ax.set_title(label +' annotation aggregated distribution')

plt.show()

print("Not assigned to any class: ")            
print(not_assigned)
# Out:
# /var/folders/mk/scd8428n18jfgh3jdthbvpz00000gn/T/ipykernel_89212/407654866.py:62: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(keys)
# Not assigned to any class:
# ['re- sistivity', 'ρ ab', 'ρc', 'ρ c', 'resis- tivity', 'resis- tivities', 'ρ', 'C', 'C(T,H)', 'C(T)', 'C(T,0)', 'SQUID magnetometer', 'Magne- tization', 'specific', 'magnetotransport\n                ', 'susceptibil-\n                    ity\n                ', 'resis- tivity\n                ', 'resistive transi- tion\n                ', 'suscepti-\n                    bility\n                ', 'χ', 'transport', 'mag- netization', 'magne- tization', 'sus- ceptibility', 'suscept- ibility\n                ', 'suscep- tibility', 'Zero-field', 'y < 6.60', 'resistiv- ity', 'standard four-probe technique', 'R', 'R − T curve', 'R-T curve', 'Eliashberg equation', 'experimental', 'estimated in the Eliashberg model', 'approximation', 'resistitively', 'resistively', 'ρ(T)', 'χAC (T ) experiments', 'RT', 'resis- tivity, ρ(T )', 'estimated', 'susceptibil- ity', 'in-plane resis-\n                    tivity', 'transport\n                ', '\n                    resistiv- ity\n                ', 'in-plane resis- tivity', '\n                    suscepti- bility\n                ', 'midpoint of the super- conducting transition', 'zero-field-cooled (ZFC)', 'suscepti- bility', 'AC sus- ceptibility', 'ρ(T )', 'C(T )', 'R-T curves', 'R-T', 'M-T', 'M-T curve', 'M-T curves', 'low field (H rms = 0.1 Oe; f = 333.3 Hz) ACS', 'ρ(T', 'ρ ab (T)', 'low-field ACS', 'ACS signal', 'ACS signals', 'low-field ACS signal', 'ACS', 'low-field bulk ACS signal', '3%, 4%, and 5%Zn', 'ρ(T,p)', 'Mass-normalized low-field (H rms = 0.1 Oe) ACS', 'mass-normalized low- field ACS', 'Mass-normalized low-field ACS', 'mass-normalized ACS', 'zero-pressure', 'x-ray diffraction', 'in-plane re- sistivity, ρ ab', 'σ ab', 'powdered mag- netization', 'M (T )', 'χ (T)', 'χ(T)', 'ac', 'χ(T )', 'high-field magne- tization', 'resistive', 'magneto- transport', 'ρ c\n                    ', 'ρ\n                    ab\n                ', 'ρ c\n                ', 'ρ ab and ρ c\n                ', 'out-of-plane re- sistivity', 'magne- tization\n                ']

# %% [markdown]
# ## Pressure
#
# the label `<pressure>`

# %%
entities_statistics = result['entities_statistics']
plot_top_10('pressure', entities_statistics)
# Out:
# count: 315
# /var/folders/mk/scd8428n18jfgh3jdthbvpz00000gn/T/ipykernel_89212/1087991225.py:21: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(keys)

# %% [markdown]
# ## Critical temperature value
#
# the label `<tcValue>`

# %%
entities_statistics = result['entities_statistics']
plot_top_10('tcValue', entities_statistics)
# Out:
# count: 1256
# /var/folders/mk/scd8428n18jfgh3jdthbvpz00000gn/T/ipykernel_89212/1087991225.py:21: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(keys)
